# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import cm, ticker
from numpy import ma

# %%
xx = [2E-7, 8E-7]
yy = [2E-7, 8E-7]
rr = [2E-8, 2E-8]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlim(0, 1E-6)
ax.set_ylim(0, 1E-6)
ax.set_title('Particles position')
ax.grid(True)
ax.axis('equal')

for x, y, r in zip(xx, yy, rr):
    circle = patches.Circle((x, y), r, edgecolor='#484', facecolor='#afa', alpha=0.5, linewidth=2)
    ax.add_patch(circle)

plt.show()

# %%
delta = 1E-8
x = np.arange(0, 1E-6, delta)
y = np.arange(0, 1E-6, delta)
X, Y = np.meshgrid(x, y)

# %%
def function(X, Y):
    Z = 0
    for x, y in zip(xx, yy):
        z = 1 / ((X - x + 1E-10)**2 + (Y - y + 1E-10)**2)
        Z = Z + z
    return Z

Z = function(X, Y)

fig, ax = plt.subplots(figsize=(7.5, 6))
ax.set_xlim(0, 1E-6)
ax.set_ylim(0, 1E-6)

cs = ax.contourf(X, Y, Z, locator=ticker.LogLocator(), cmap=cm.PuBu_r)
cbar = fig.colorbar(cs)

ax.grid()
ax.set_title('Particles position')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.axis('equal')
plt.show()
