# %% [markdown]
# url https://stackoverflow.com/a/73745937/9475509

# %%
import numpy as np
from matplotlib import pyplot as plt
import ffmpegio

np.random.seed(0)
fig, ax = plt.subplots(figsize=(9, 4),dpi=300)
ln, = ax.plot([])
ax.set_xlim([0, 1000])
ax.set_ylim([-1, 1])
ax.grid(True)

with ffmpegio.open(
  "writer_test.mp4", # output file name
  "wv", # open file in write-video mode
  1, # framerate in frames/second
  pix_fmt="yuv420p", # specify the pixel format (default is yuv444p)
  overwrite=True
) as writer:
    for i in range(20):
        x = np.arange(1000)
        t = np.random.randn(1000)
        y = np.sin(2 * np.pi * t)
        ln.set_data(x, y)
        writer.write(fig)
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# Cell In[2], line 24
#      22 y = np.sin(2 * np.pi * t)
#      23 ln.set_data(x, y)
# ---> 24 writer.write(fig)
#
# File V:\tf\Lib\site-packages\ffmpegio\streams\SimpleStreams.py:465, in SimpleWriterBase.write(self, data)
#     449 """Write the given numpy.ndarray object, data, and return the number
#     450 of bytes written (always equal to the number of data frames/samples,
#     451 since if the write fails an OSError will be raised).
#    (...)
#     459
#     460 """
#     462 if self._cfg:
#     463     # if FFmpeg not yet started, finalize the configuration with
#     464     # the data and start
# --> 465     self._open(data)
#     467 logger.debug("[writer main] writing...")
#     469 try:
#
# File V:\tf\Lib\site-packages\ffmpegio\streams\SimpleStreams.py:394, in SimpleWriterBase._open(self, data)
#     391 def _open(self, data=None):
#     392     # if data array is given, finalize the FFmpeg configuration with it
#     393     if data is not None:
# --> 394         self._finalize_with_data(data)
#     396     # start FFmpeg
#     397     self._proc = ffmpegprocess.Popen(**self._cfg)
#
# File V:\tf\Lib\site-packages\ffmpegio\streams\SimpleStreams.py:538, in SimpleVideoWriter._finalize_with_data(self, data)
#     536 ffmpeg_args = self._cfg["ffmpeg_args"]
#     537 inopts = ffmpeg_args["inputs"][0][1]
# --> 538 shape, dtype = plugins.get_hook().video_info(obj=data)
#     539 s, pix_fmt = utils.guess_video_format(shape, dtype)
#     541 configure.build_basic_vf(
#     542     ffmpeg_args, configure.check_alpha_change(ffmpeg_args, -1)
#     543 )
#
# TypeError: cannot unpack non-iterable NoneType object
